# %% [markdown]
# <a href="https://colab.research.google.com/github/Gabriel107x/GoogleColab1/blob/main/Bar_plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
country = ['INDIA','JAPAN','MEXICO','COLOMBIA','GERMANY']
population = [1000,100,200,50,80]

# %%
plt.bar(country,population, width=0.5, color=['red','blue'])
plt.title('Population by country')
plt.xlabel('Country')
plt.ylabel('Population')
plt.xticks(np.arange(5),('India', 'Japon','Mexico', 'Colombia', 'Alemania'), rotation=45)
plt.show()

# %%
plt.barh(country,population)
# Out:
# <BarContainer object of 5 artists>
